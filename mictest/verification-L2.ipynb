# %% [markdown]
# # Notebook to verify counters and stuff
#
# Author: Brain Gravelle (gravelle@cs.uoregon.edu)
#
#
# All this is using the taucmdr python libraries from paratools
# http://taucommander.paratools.com/

# %% [markdown]
# ## Imports
# This section imports necessary libraies, the metrics.py and utilities.py files and sets up the window.

# %%
# A couple of scripts to set the environent and import data from a .tau set of results
from utilities import *
from metrics import *
# Plotting, notebook settings:
# %matplotlib inline  
#plt.rcParams.update({'font.size': 16})
import numbers
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.float_format', lambda x: '%.2e' % x)
pd.set_option('display.max_columns',100)
pd.set_option('max_colwidth', 70)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Getting Data
#
# TAU Commander uses TAU to run the application and measure it using runtime sampling techniques (similar to Intel VTune). Many customization options are available. For example, we may consider each function regardless of calling context, or we may decide to enable callpath profiling to see each context separately.
#
# From the talapas_scaling application the following experiments are available. These use Talapas (with 28 thread Broadwell processors) and the build-ce (realistic) option for mkFit. The first six experiments use the --num-thr option to set the thread count which is intended to perform threading within the events. the last two add the --num-ev-thr option to set the event threads, so that all threads are used to process events in parallel and each event is processed by a single thread.
# * manual_scaling_Large_talapas
# * manual_scaling_Large_talapas_fullnode
# * manual_scaling_TTbar70_talapas
# * manual_scaling_TTbar70_talapas_fullnode
# * manual_scaling_TTbar35_talapas
# * manual_scaling_TTbar35_talapas_fullnode
# * ev_thr_scaling_Large_talapas
# * ev_thr_scaling_Large_talapas_fullnode
#
# Additionally available in the cori_scaling application are the following. These were run on NERSC's Cori on the KNL with the default memory settings (quad - 1 NUMA domain, cache - MCDRAM as direct mapped cache). See http://www.nersc.gov/users/computational-systems/cori/running-jobs/advanced-running-jobs-options/ for more info on the KNL modes. Similar to the talapas scaling they use the build-ce option and threading within each event.
# * manual_scaling_TTbar35

# %% [markdown]
# ### Importing Scaling Data
# Here we import the data. In this case we are using Cori data from the experiments with the threads working within each event using the TTbar35 file. Note that this box will take 10 or more minutes to run; please go enjoy a coffee while you wait.

# %%
# application = "talapas_scaling"
# experiment  = "manual_scaling_TTbar70_talapas"
# experiment  = "manual_scaling_Large_talapas"
# experiment = "ev_thr_scaling_Large_talapas"

# application = "cori_scaling"
# experiment  = "manual_scaling_TTbar35"

application = "cache_test"
experiment  = "L2"

path  = ".tau/" + application + "/" + experiment + "/"
# note that this function takes a long time to run, so only rerun if you must
metric_data  = get_pandas_scaling(path, callpaths=True)
# metric_data = remove_erroneous_threads(metric_data,  [1, 8, 16, 32, 48, 56])
# metric_data = remove_erroneous_threads(metric_data,  [1, 8, 16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256])

# %% [markdown]
# #### A list of metrics

# %%
add_metric_to_scaling_data(metric_data, add_L2_missrate)
print_available_metrics(metric_data,True)
print metric_data.keys()
# Out:
# PAPI_L2_TCA
# DERIVED_L2_MISSRATE
# PAPI_L2_TCM
# [16]

# %% [markdown]
# #### Metric metadata

# %%
#print_metadata(metric_data[1])

# %%
L2_data = select_metric_from_scaling(metric_data, 'DERIVED_L2_MISSRATE')
L2_MR = filter_libs_out(L2_data[16]).sort_values(by='Inclusive',ascending=False)[["Inclusive"]]
L2_MR.head(200)
# Out:
#                                                                                Inclusive
# thread region
# 1      [SUMMARY] Matriplex::MatriplexSym<float, 6, 8>::operator=(Matriplex...   1.27e+02
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   1.27e+02
# 13     [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   3.13e+01
#        [SUMMARY] __lll_lock_wait_private                                        3.13e+01
# 12     [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   2.62e+01
#        [SUMMARY] RadixSort::Sort(float const*, unsigned int)                    2.62e+01
# 11     [SUMMARY] ROOT::Math::SVector<float, 6u>::SVector(ROOT::Math::SVect...   2.26e+01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   2.26e+01
# 9      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   2.24e+01
#        [SUMMARY] helixAtZ(Matriplex::Matriplex<float, 6, 1, 8> const&, Mat...   2.24e+01
# 1      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   1.71e+01
#        [SUMMARY] (anonymous namespace)::MultHelixPropTransp(Matriplex::Mat...   1.71e+01
# 10     [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   1.67e+01
#        [SUMMARY] MkFinder::FindCandidatesCloneEngine(LayerOfHits const&, C...   1.67e+01
# 3      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   1.08e+01
#        [SUMMARY] __GI___sched_yield                                             1.08e+01
# 2      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   9.35e+00
#        [SUMMARY] __lll_lock_wait_private                                        9.35e+00
# 0      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   7.15e+00
#        [SUMMARY] __libm_tanf_l9                                                 7.15e+00
#        [SUMMARY] Matriplex::MatriplexSym<float, 6, 8>::CopyIn(int, float c...   6.47e+00
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   6.47e+00
#        [SUMMARY] Matriplex::Matriplex<int, 16, 1, 8>::At(int, int, int)         4.85e+00
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   4.85e+00
# 2      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   4.34e+00
#        [SUMMARY] LayerOfHits::alloc_hits(int)                                   4.34e+00
# 6      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   4.30e+00
#        [SUMMARY] Matriplex::MatriplexSym<float, 6, 8>::operator=(Matriplex...   4.30e+00
# 3      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   4.24e+00
#        [SUMMARY] void _INTERNALc4f9cdd2::helixAtRFromIterativeCCS_impl<Mat...   4.24e+00
# ...                                                                                  ...
# 0      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   9.06e-01
#        [SUMMARY] FMA(__m256 const&, __m256 const&, __m256 const&)               9.06e-01
# 8      [SUMMARY] helixAtZ(Matriplex::Matriplex<float, 6, 1, 8> const&, Mat...   8.94e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.94e-01
# 0      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.89e-01
#        [SUMMARY] Matriplex::Matriplex<float, 6, 6, 8>::operator()(int, int...   8.89e-01
# 11     [SUMMARY] void _INTERNALc4f9cdd2::helixAtRFromIterativeCCS_impl<Mat...   8.74e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.74e-01
# 13     [SUMMARY] Matriplex::MatriplexSym<float, 6, 8>::operator=(Matriplex...   8.74e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.74e-01
# 12     [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.68e-01
#        [SUMMARY] Matriplex::MatriplexSym<float, 6, 8>::CopyIn(int, float c...   8.68e-01
# 4      [SUMMARY] Matriplex::MatriplexSym<float, 6, 8>::CopyOut(int, float*...   8.66e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.66e-01
# 8      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.65e-01
#        [SUMMARY] FMA(__m256 const&, __m256 const&, __m256 const&)               8.65e-01
# 7      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.48e-01
#        [SUMMARY] __GI___sched_yield                                             8.48e-01
# 0      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.35e-01
#        [SUMMARY] __svml_sincosf8_l9                                             8.35e-01
# 8      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.17e-01
#        [SUMMARY] (anonymous namespace)::Chi2Similarity(Matriplex::Matriple...   8.17e-01
# 2      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   8.01e-01
#        [SUMMARY] void _INTERNALc4f9cdd2::helixAtRFromIterativeCCS_impl<Mat...   8.01e-01
# 0      [SUMMARY] Matriplex::Matriplex<float, 3, 1, 8>::SlurpIn(char const*...   7.98e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   7.98e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   7.90e-01
#        [SUMMARY] Event::read_in(DataFile&, _IO_FILE*)                           7.90e-01
# 11     [SUMMARY] Matriplex::CramerInverterSym<float, 2, 8>::Invert(Matripl...   7.60e-01
#        [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   7.60e-01
#
# [200 rows x 1 columns]

# %%
TCA_data = select_metric_from_scaling(metric_data, 'PAPI_L2_TCA')
TCA = filter_libs_out(TCA_data[16]).sort_values(by='Inclusive',ascending=False)[["Inclusive"]]
TCA.head(10)
# Out:
#                                                                                        Inclusive
# context thread region
# 0       0      [SUMMARY] .TAU application                                               3.11e+08
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application                3.11e+08
#                [SUMMARY] __lll_lock_wait_private                                        9.49e+07
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   9.49e+07
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMP...   9.49e+07
#                [SUMMARY] __GI_madvise                                                   9.49e+07
#         6      [SUMMARY] .TAU application                                               2.74e+07
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application                2.74e+07
#         14     [SUMMARY] .TAU application  => [CONTEXT] .TAU application                2.74e+07
#                [SUMMARY] .TAU application                                               2.74e+07

# %%
TCM_data = select_metric_from_scaling(metric_data, 'PAPI_L2_TCM')
TCM = filter_libs_out(TCM_data[16]).sort_values(by='Inclusive',ascending=False)[["Inclusive"]]
TCM.head(10)
# Out:
#                                                                           Inclusive
# context thread region
# 0       0      [SUMMARY] .TAU application                                  1.23e+08
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application   1.23e+08
#         7      [SUMMARY] .TAU application                                  1.38e+07
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application   1.38e+07
#         13     [SUMMARY] .TAU application                                  1.35e+07
#                [SUMMARY] .TAU application  => [CONTEXT] .TAU application   1.35e+07
#         11     [SUMMARY] .TAU application  => [CONTEXT] .TAU application   1.35e+07
#                [SUMMARY] .TAU application                                  1.35e+07
#         5      [SUMMARY] .TAU application  => [CONTEXT] .TAU application   1.33e+07
#                [SUMMARY] .TAU application                                  1.33e+07

# %%
TCM_data[16][TCM_data[16].index.get_level_values('region').str.contains("__lll_lock_wait_private")]['Inclusive']
# Out:
# context  thread  region
# 0        1       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    6.92e+03
#                  [SUMMARY] __lll_lock_wait_private                                                                 6.92e+03
#          2       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    2.40e+04
#                  [SUMMARY] __lll_lock_wait_private                                                                 2.40e+04
#          5       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    3.69e+04
#                  [SUMMARY] __lll_lock_wait_private                                                                 3.69e+04
#          6       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    2.24e+04
#                  [SUMMARY] __lll_lock_wait_private                                                                 2.24e+04
#          7       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    7.45e+03
#                  [SUMMARY] __lll_lock_wait_private                                                                 7.45e+03
#          8       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    1.23e+03
#                  [SUMMARY] __lll_lock_wait_private                                                                 1.23e+03
#          9       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    1.49e+03
#                  [SUMMARY] __lll_lock_wait_private                                                                 1.49e+03
#          11      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    3.19e+04
#                  [SUMMARY] __lll_lock_wait_private                                                                 3.19e+04
#          12      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    2.27e+03
#                  [SUMMARY] __lll_lock_wait_private                                                                 2.27e+03
#          13      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    6.07e+04
#                  [SUMMARY] __lll_lock_wait_private                                                                 6.07e+04
#          14      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] __lll_lock_wait_private    2.81e+03
#                  [SUMMARY] __lll_lock_wait_private                                                                 2.81e+03
# Name: Inclusive, dtype: float64

# %%
TCA_data[16][TCA_data[16].index.get_level_values('region').str.contains("applyMaterialEffects\(Matriplex::Matriplex")]['Inclusive']
# Out:
# context  thread  region
# 0        2       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    6.70e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 6.70e+05
#          4       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    1.11e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 1.11e+05
#          5       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    9.46e+04
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 9.46e+04
#          6       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    2.57e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 2.57e+05
#          7       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    1.89e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 1.89e+05
#          11      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    4.83e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 4.83e+05
#          13      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    1.74e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 1.74e+05
#          15      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    3.15e+05
#                  [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 3.15e+05
# Name: Inclusive, dtype: float64

# %%
L2_data[16][L2_data[16].index.get_level_values('region').str.contains("applyMaterialEffects\(Matriplex::Matriplex")]['Inclusive']
# Out:
# thread  region
# 4       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    7.18e-01
#         [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 7.18e-01
# 6       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    8.78e-02
#         [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 8.78e-02
# 7       [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    5.05e-01
#         [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 5.05e-01
# 11      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    4.06e-02
#         [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 4.06e-02
# 15      [SUMMARY] .TAU application  => [CONTEXT] .TAU application  => [SAMPLE] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)    3.00e-01
#         [SUMMARY] applyMaterialEffects(Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int)                                                                 3.00e-01
# Name: Inclusive, dtype: float64
