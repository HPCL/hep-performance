# %% [markdown]
# # Hotspot Calculations for HEP
#
# Author: Brain Gravelle (gravelle@cs.uoregon.edu)
#
#
# All this is using the taucmdr python libraries from paratools
# http://taucommander.paratools.com/

# %% [markdown]
# ## Imports

# %%
from utilities import *
from metrics import *

# %% [markdown]
# ## Getting the data from the tau profiles.
#
# You need a .tau directory in the same dir as this ipynb with all the relavant data and xml stuff that they put in there to make this thing work.
#
# The results of the next box is a dict with keys as the metrics and the data in pandas. It should also print a list of the metrics.
#
# The functions that import the data are found in utilities.py
#
# Note:
# * make sure that application and experiment are defined correctly
#     * use 'tau dash' in the project folder to check options
# * ALL trials from the experiment will be read. only one set of results will be kept per metric
# * meta data about the machine and such is stored under the key METADATA
#
# Available experiments:
# * multi - data based on a toy version of the program.
# * realistic  - data based on a run of the program with the TT35PU... input file, 10 threads, and 100 events
# * event_scaling_TT35  - data based on a run of the program with the TT35PU... input file, 10 threads, and events ranging from 10 to 100
# * TT70  - data based on a run of the program with the TT70PU... input file, 10 threads, and 100 events
# * event_scaling_TT35  - data based on a run of the program with the TT70PU... input file, 10 threads, and events ranging from 10 to 100
# * note that the event scaling runs don't have a function to properly load the data yet

# %%
application = "mictest_sampling"
experiment  = "TTbar70"

path = ".tau/" + application + "/" + experiment + "/"
expr_intervals = get_pandas(path)

#level_inds = {'trial': 0, 'rank': 1, 'context': 2, 'thread': 3, 'region': 4}
print(expr_intervals.keys())
print("")
print(expr_intervals['PAPI_TOT_INS'].columns)
print("")
print(expr_intervals['PAPI_TOT_INS'].index.names)
print("")
print_metadata(expr_intervals)

expr_intervals['PAPI_TOT_INS'].sort_values(by='Inclusive',ascending=False)[["Inclusive"]].head(10)
# Out:
# ['PAPI_NATIVE_UOPS_RETIRED:SCALAR_SIMD', 'PAPI_L2_TCA', 'PAPI_NATIVE_LLC_MISSES', 'PAPI_RES_STL', 'PAPI_L2_TCM', 'PAPI_TOT_INS', 'PAPI_NATIVE_UOPS_RETIRED:PACKED_SIMD', 'PAPI_LST_INS', 'PAPI_NATIVE_LLC_REFERENCES', 'PAPI_L1_TCM', 'PAPI_TOT_CYC', 'METADATA']
#
# Index([u'Calls', u'Subcalls', u'Exclusive', u'Inclusive', u'ProfileCalls'], dtype='object')
#
# [u'rank', u'context', u'thread', u'region']
#
# TAU_MAX_THREADS                                    512
# TAU_CUDA_BINARY_EXE                                None
# TAU_MEASURE_TAU                                    off
# Memory Size                                        115370324 kB
# TAU_TRACK_SIGNALS                                  off
# TAU_TRACK_IO_PARAMS                                off
# CPU MHz                                            1003.601
# Local Time                                         2018-02-17T23:58:48-08:00
# CPU Type                                           Intel(R) Xeon Phi(TM) CPU 7250 @ 1.40GHz
# TAU_OUTPUT_CUDA_CSV                                off
# TAU_EBS_INCLUSIVE                                  0 usec
# Node Name                                          grover
# TAU_CALLPATH_DEPTH                                 100
# CPU Cores                                          68
# OS Machine                                         x86_64
# TAU_SAMPLING                                       on
# Cache Size                                         1024 KB
# TAU_PAPI_MULTIPLEXING                              off
# TAU_EBS_KEEP_UNRESOLVED_ADDR                       off
# TAU_THROTTLE                                       on
# TAU Architecture                                   default
# TAU_COMPENSATE                                     off
# TAU_CALLSITE_DEPTH                                 1
# TAU_SHOW_MEMORY_FUNCTIONS                          off
# OS Version                                         #1 SMP Thu Oct 27 15:14:31 PDT 2016
# Starting Timestamp                                 1518940728142426
# TAU_SIGNALS_GDB                                    off
# TAU Version                                        2.27-git
# TAU_TRACK_MEMORY_LEAKS                             off
# TAU_MEMDBG_PROTECT_FREE                            off
# TAU Config                                          -tag=3eb21538 -arch=x86_64 -cc=icc -c++=icpc -fortran=intel -bfd=/storage/users/gravelle/taucmdr-enterprise-2/system/binutils/a729a734 -papi=/home/users/norris/soft/papi-grover -unwind=/storage/users/gravelle/taucmdr-enterprise-2/system/libunwind/2b3dd830 -tbb -useropt=-O2#-g#-DTAU_MAX_THREADS=512#-DTAU_MAX_METRICS=32#-DTAU_MAX_COUNTERS=32
# TAU_EBS_SAMPLES_DROPPED_TAU_3                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_2                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_1                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_0                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_7                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_6                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_5                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_4                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_9                      3
# TAU_EBS_SAMPLES_DROPPED_TAU_8                      3
# TAU_OPENMP_RUNTIME_EVENTS                          on
# TAU_BFD_LOOKUP                                     on
# TAU_EBS_UNWIND_DEPTH                               10
# TAU_MEMDBG_PROTECT_BELOW                           off
# TAU_THROTTLE_NUMCALLS                              100000
# TAU_EBS_PERIOD                                     50000
# OS Name                                            Linux
# Hostname                                           grover
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_8                0
# UTC Time                                           2018-02-18T07:58:48Z
# Metric Name                                        TIME
# Timestamp                                          1518940728196074
# TAU_TRACK_CUDA_SASS                                off
# TAU_TRACK_UNIFIED_MEMORY                           off
# username                                           gravelle
# TAU_OPENMP_RUNTIME                                 on
# TAU_TRACE_FORMAT                                   tau
# TAU_OPENMP_RUNTIME_STATES                          off
# pid                                                63764
# TAU_MEMDBG_PROTECT_ABOVE                           off
# Ending Timestamp                                   1518940774253168
# TAU_PROFILE_FORMAT                                 profile
# Executable                                         /storage/users/gravelle/mictest_sampling/mkFit/mkFit
# TAU_TRACK_CUDA_INSTRUCTIONS                        None
# TAU Makefile                                       /storage/users/gravelle/taucmdr-enterprise-2/system/tau/tau-2.27/x86_64/lib/Makefile.tau-3eb21538-icpc-papi-tbb
# TAU_TRACK_HEADROOM                                 off
# CPU Vendor                                         GenuineIntel
# TAU_PROFILE                                        on
# TAU_TRACK_CUDA_CDP                                 off
# Command Line                                       ./mkFit/mkFit --cmssw-n2seeds --input-file TTbar70PU-memoryFile.fv3.clean.writeAll.recT.072617.bin --build-ce --num-thr 10 --num-events 200
# TAU_TRACK_HEAP                                     off
# TAU_CALLPATH                                       on
# tid                                                63764
# TAU_TRACE                                          off
# TAU_THROTTLE_PERCALL                               10
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_0                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_1                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_2                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_3                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_4                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_5                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_6                0
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_7                0
# TAU_IBM_BG_HWP_COUNTERS                            off
# TAU_EBS_SAMPLES_DROPPED_SUSPENDED_9                0
# CWD                                                /storage/users/gravelle/mictest_sampling
# TAU_TRACK_MEMORY_FOOTPRINT                         off
# TAU_CALLSITE                                       on
# TAU_EBS_UNWIND                                     on
# TAU_EBS_SAMPLES_TAKEN_9                            924
# TAU_EBS_SAMPLES_TAKEN_8                            924
# TAU_CUPTI_API                                      runtime
# OS Release                                         4.8.4
# TAU_EBS_SAMPLES_TAKEN_1                            924
# TAU_EBS_SAMPLES_TAKEN_0                            924
# TAU_EBS_SAMPLES_TAKEN_3                            924
# TAU_EBS_SAMPLES_TAKEN_2                            924
# TAU_EBS_SAMPLES_TAKEN_5                            924
# TAU_EBS_SAMPLES_TAKEN_4                            924
# TAU_EBS_SAMPLES_TAKEN_7                            924
# TAU_EBS_SAMPLES_TAKEN_6                            924
#                                                                          Inclusive
# rank context thread region
# 0    0       0      [SUMMARY] Event::clean_cms_seedtracks()             2518060658
#                     [SUMMARY] std::__detail::_Mod_range_hashing::op...  2039378190
#              5      [SUMMARY] syscall                                   1780321980
#              6      [SUMMARY] syscall                                   1734039953
#              7      [SUMMARY] syscall                                   1642961484
#              4      [SUMMARY] syscall                                   1582326153
#              1      [SUMMARY] syscall                                   1529560730
#              3      [SUMMARY] syscall                                   1523641615
#              9      [SUMMARY] syscall                                   1476745736
#              2      [SUMMARY] syscall                                   1451258013

# %%
application = "mictest_sampling"
experiment  = "TTbar70"

path = ".tau/" + application + "/" + experiment + "/"
e = get_pandas_multi_run(path)

# %%
print(len(e['PAPI_TOT_INS']))

e['PAPI_TOT_INS'][0].sort_values(by='Inclusive',ascending=False)[["Inclusive"]].head(10)
# Out:
# 1
#                                                                          Inclusive
# rank context thread region
# 0    0       0      [SUMMARY] Event::clean_cms_seedtracks()             2518060658
#                     [SUMMARY] std::__detail::_Mod_range_hashing::op...  2039378190
#              5      [SUMMARY] syscall                                   1780321980
#              6      [SUMMARY] syscall                                   1734039953
#              7      [SUMMARY] syscall                                   1642961484
#              4      [SUMMARY] syscall                                   1582326153
#              1      [SUMMARY] syscall                                   1529560730
#              3      [SUMMARY] syscall                                   1523641615
#              9      [SUMMARY] syscall                                   1476745736
#              2      [SUMMARY] syscall                                   1451258013

# %% [markdown]
# ### Importing Scaling Data
# No data yet, so don't use this

# %%
# scale_intervals = get_pandas_scaling('.tau/mictest_sampling/scaling/')

#level_inds = {'trial': 0, 'rank': 1, 'context': 2, 'thread': 3, 'region': 4}
# print(scale_intervals.keys())

# print(scale_intervals[10].keys())
# print(scale_intervals[10]['PAPI_TOT_INS'].columns)
# print(scale_intervals[10]['PAPI_TOT_INS'].index.names)

# scale_intervals[10]['PAPI_TOT_INS'][["Inclusive"]].head(10)

# %% [markdown]
# ## Adding metrics
#
# TODO figure this out
#   - scale function
#   - separate threads
#
# These are functions that can add metrics to the dictionary

# %%
add_CPI(expr_intervals)
print(expr_intervals.keys())

expr_intervals['DERIVED_CPI'].head(10)
# Out:
# ['PAPI_NATIVE_UOPS_RETIRED:SCALAR_SIMD', 'PAPI_L2_TCA', 'PAPI_NATIVE_LLC_MISSES', 'PAPI_RES_STL', 'PAPI_L2_TCM', 'PAPI_TOT_INS', 'PAPI_NATIVE_UOPS_RETIRED:PACKED_SIMD', 'DERIVED_CPI', 'PAPI_LST_INS', 'PAPI_NATIVE_LLC_REFERENCES', 'PAPI_L1_TCM', 'PAPI_TOT_CYC', 'METADATA']
#                                                                       Calls  \
# context thread region
# 0       0      [SUMMARY] (anonymous namespace)::MultHelixProp(...  2.000000
#                [SUMMARY] (anonymous namespace)::MultHelixPropE...  1.333333
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...  0.333333
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...  1.000000
#                [SUMMARY] (anonymous namespace)::sortCandListBy...  0.666667
#                [SUMMARY] CandCloner::ProcessSeedRange(int, int)    3.000000
#                [SUMMARY] Event::clean_cms_seedtracks()             0.900990
#                [SUMMARY] FMA(__m256 const&, __m256 const&, __m...  1.000000
#                [SUMMARY] Hit::Hit()                                1.000000
#                [SUMMARY] Hit::mcHitID() const                      1.000000
#
#                                                                    Exclusive  \
# context thread region
# 0       0      [SUMMARY] (anonymous namespace)::MultHelixProp(...   5.410783
#                [SUMMARY] (anonymous namespace)::MultHelixPropE...   2.828229
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...   0.863261
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...   2.951659
#                [SUMMARY] (anonymous namespace)::sortCandListBy...   1.388162
#                [SUMMARY] CandCloner::ProcessSeedRange(int, int)     8.086814
#                [SUMMARY] Event::clean_cms_seedtracks()              1.611285
#                [SUMMARY] FMA(__m256 const&, __m256 const&, __m...   1.615924
#                [SUMMARY] Hit::Hit()                                 1.431340
#                [SUMMARY] Hit::mcHitID() const                       2.519181
#
#                                                                    Inclusive  \
# context thread region
# 0       0      [SUMMARY] (anonymous namespace)::MultHelixProp(...   5.410783
#                [SUMMARY] (anonymous namespace)::MultHelixPropE...   2.828229
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...   0.863261
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...   2.951659
#                [SUMMARY] (anonymous namespace)::sortCandListBy...   1.388162
#                [SUMMARY] CandCloner::ProcessSeedRange(int, int)     8.086814
#                [SUMMARY] Event::clean_cms_seedtracks()              1.611285
#                [SUMMARY] FMA(__m256 const&, __m256 const&, __m...   1.615924
#                [SUMMARY] Hit::Hit()                                 1.431340
#                [SUMMARY] Hit::mcHitID() const                       2.519181
#
#                                                                    ProfileCalls  \
# context thread region
# 0       0      [SUMMARY] (anonymous namespace)::MultHelixProp(...           NaN
#                [SUMMARY] (anonymous namespace)::MultHelixPropE...           NaN
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...           NaN
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...           NaN
#                [SUMMARY] (anonymous namespace)::sortCandListBy...           NaN
#                [SUMMARY] CandCloner::ProcessSeedRange(int, int)             NaN
#                [SUMMARY] Event::clean_cms_seedtracks()                      NaN
#                [SUMMARY] FMA(__m256 const&, __m256 const&, __m...           NaN
#                [SUMMARY] Hit::Hit()                                         NaN
#                [SUMMARY] Hit::mcHitID() const                               NaN
#
#                                                                    Subcalls
# context thread region
# 0       0      [SUMMARY] (anonymous namespace)::MultHelixProp(...       NaN
#                [SUMMARY] (anonymous namespace)::MultHelixPropE...       NaN
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...       NaN
#                [SUMMARY] (anonymous namespace)::MultHelixPropT...       NaN
#                [SUMMARY] (anonymous namespace)::sortCandListBy...       NaN
#                [SUMMARY] CandCloner::ProcessSeedRange(int, int)         NaN
#                [SUMMARY] Event::clean_cms_seedtracks()                  NaN
#                [SUMMARY] FMA(__m256 const&, __m256 const&, __m...       NaN
#                [SUMMARY] Hit::Hit()                                     NaN
#                [SUMMARY] Hit::mcHitID() const                           NaN

# %% [markdown]
# ### Metric Generation
#
# gen_metric generates the boring bits of the metric adding function
# * List the metrics you will use
# * provide a name for the new metric
# * paste into metrics.py
# * implement the math bit

# %%
print(gen_metric(['PAPI_NATIVE_UOPS_RETIRED_PACKED_SIMD', 'PAPI_L1_TCM'], "VECTOR_PER_MISS"))
# Out:
# def add_VECTOR_PER_MISS(metrics):
# 	if (not metrics.has_key(PAPI_NATIVE_UOPS_RETIRED_PACKED_SIMD)):
# 		print 'ERROR adding VECTOR_PER_MISS to metric dictionary'
# 		return False	a0 = metrics[PAPI_NATIVE_UOPS_RETIRED_PACKED_SIMD].copy()
# 	a0.index = a0.index.droplevel()
# 	u0 = a0.unstack()
# 	if (not metrics.has_key(PAPI_L1_TCM)):
# 		print 'ERROR adding VECTOR_PER_MISS to metric dictionary'
# 		return False	a1 = metrics[PAPI_L1_TCM].copy()
# 	a1.index = a1.index.droplevel()
# 	u1 = a1.unstack()
# 	metrics[VECTOR_PER_MISS] = "PLEASE IMPLEMENT THIS PART"
#
# 	return True

# %% [markdown]
# ## Interesting bits
#
# This is where the stuff is actually calculated.

# %%
# levels: 0=trial, 1=node, 2=context, 3=thread, 4=region name -- deprecated
# levels: 0=rank, 1=context, 2=thread, 3=region name -- deprecated

       
n=10

def get_hotspots(metric):
    print('selected metric: %s\n' %metric)
    hotspots(expr_intervals[metric], n, 1)

    print('='*80)

    filtered_dfs = filter_libs_out(expr_intervals[metric])
    hotspots(filtered_dfs, n, 1)
    
get_hotspots('PAPI_TOT_CYC')
# Out:
# selected metric: PAPI_TOT_CYC
#
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] Event::clean_cms_seedtracks()  (4057314016)
# 2: [SUMMARY] syscall  (3188799261)
# 3: [SUMMARY] std::__detail::_Mod_range_hashing::operator()(unsigned long, unsigned long) const  (2713533683)
# 4: [SUMMARY] _int_malloc  (2526790408)
# 5: [SUMMARY] MkFinder::SelectHitIndices(LayerOfHits const&, int)  (2215543058)
# 6: [SUMMARY] __svml_sincosf8_l9  (2126595723)
# 7: [SUMMARY] _int_free  (2027594045)
# 8: [SUMMARY] __GI___libc_malloc  (1814165933)
# 9: [SUMMARY] UNRESOLVED /storage/packages/intel/vtune_amplifier_xe_2017.5.0.526192/lib64/libstdc++.so.6.0.20 (1706600094)
# 10: [SUMMARY] __intel_mic_avx512f_memset  (1666113549)
# ================================================================================
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] Event::clean_cms_seedtracks()  (4057314016)
# 2: [SUMMARY] _int_malloc  (2526790408)
# 3: [SUMMARY] MkFinder::SelectHitIndices(LayerOfHits const&, int)  (2215543058)
# 4: [SUMMARY] __svml_sincosf8_l9  (2126595723)
# 5: [SUMMARY] _int_free  (2027594045)
# 6: [SUMMARY] __GI___libc_malloc  (1814165933)
# 7: [SUMMARY] UNRESOLVED /storage/packages/intel/vtune_amplifier_xe_2017.5.0.526192/lib64/libstdc++.so.6.0.20 (1706600094)
# 8: [SUMMARY] __intel_mic_avx512f_memset  (1666113549)
# 9: [SUMMARY] malloc_consolidate  (1168105443)
# 10: [SUMMARY] MkFinder::FindCandidatesCloneEngine(LayerOfHits const&, CandCloner&, int, int, FindingFoos const&)  (979140582)

# %%
get_hotspots('DERIVED_CPI')
# Out:
# selected metric: DERIVED_CPI
#
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] _ZN9__gnu_cxx13new_allocatorIN8MkFinder11IdxChi2ListEE9constructIS2_IRKS2_EEEvPT_DpOT0_  (213.944798734)
# 2: [SUMMARY] CandCloner::add_cand(int, MkFinder::IdxChi2List const&)  (167.911727744)
# 3: [SUMMARY] CandCloner::ProcessSeedRange(int, int)  (152.986385326)
# 4: [SUMMARY] __gnu_cxx::new_allocator<std::pair<int, int> >::allocate(unsigned long, void const*)  (67.0419350112)
# 5: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::CopyIn(int, float const*)  (51.053994364)
# 6: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::CopyOut(int, float*) const  (36.4479128446)
# 7: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::operator=(Matriplex::Matriplex<float, 6, 1, 8> const&)  (29.0821664127)
# 8: [SUMMARY] Matriplex::Matriplex<float, 1, 1, 8>::operator()(int, int, int)  (18.3002056245)
# 9: [SUMMARY] Matriplex::Matriplex<float, 3, 1, 8>::ConstAt(int, int, int) const  (15.5222161589)
# 10: [SUMMARY] MkFinder::IdxChi2List* std::__copy_move_backward<true, true, std::random_access_iterator_tag>::__copy_move_b<MkFinder::IdxChi2List>(MkFinder::IdxChi2List const*, MkFinder::IdxChi2List const*, MkFinder::IdxChi2List*)  (14.1507319884)
# ================================================================================
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] _ZN9__gnu_cxx13new_allocatorIN8MkFinder11IdxChi2ListEE9constructIS2_IRKS2_EEEvPT_DpOT0_  (213.944798734)
# 2: [SUMMARY] CandCloner::add_cand(int, MkFinder::IdxChi2List const&)  (167.911727744)
# 3: [SUMMARY] CandCloner::ProcessSeedRange(int, int)  (152.986385326)
# 4: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::CopyIn(int, float const*)  (51.053994364)
# 5: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::CopyOut(int, float*) const  (36.4479128446)
# 6: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::operator=(Matriplex::Matriplex<float, 6, 1, 8> const&)  (29.0821664127)
# 7: [SUMMARY] Matriplex::Matriplex<float, 1, 1, 8>::operator()(int, int, int)  (18.3002056245)
# 8: [SUMMARY] Matriplex::Matriplex<float, 3, 1, 8>::ConstAt(int, int, int) const  (15.5222161589)
# 9: [SUMMARY] (anonymous namespace)::MultHelixProp(Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::MatriplexSym<float, 6, 8> const&, Matriplex::Matriplex<float, 6, 6, 8>&)  (14.0364818629)
# 10: [SUMMARY] (anonymous namespace)::MultHelixPropTransp(Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&)  (13.832564876)

# %%
add_L1_missrate(expr_intervals)
get_hotspots('DERIVED_L1_MISSRATE')
# Out:
# selected metric: DERIVED_L1_MISSRATE
#
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] __GI___sched_yield  (21.2451109411)
# 2: [SUMMARY] (anonymous namespace)::MultHelixPropTransp(Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&)  (9.00434493368)
# 3: [SUMMARY] Matriplex::Matriplex<int, 1, 1, 8>::operator()(int, int, int) const  (5.63956221722)
# 4: [SUMMARY] std::sqrt(float)  (1.65987949413)
# 5: [SUMMARY] LayerInfo::is_within_r_sensitive_region(float, float) const  (0.393683020968)
# 6: [SUMMARY] CandCloner::add_cand(int, MkFinder::IdxChi2List const&)  (0.344553093074)
# 7: [SUMMARY] propagateHelixToRMPlex(Matriplex::MatriplexSym<float, 6, 8> const&, Matriplex::Matriplex<float, 6, 1, 8> const&, Matriplex::Matriplex<int, 1, 1, 8> const&, Matriplex::Matriplex<float, 3, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int, bool)  (0.266263277871)
# 8: [SUMMARY] CandCloner::ProcessSeedRange(int, int)  (0.245307338962)
# 9: [SUMMARY] Matriplex::MatriplexSym<float, 3, 8>::SlurpIn(char const*, int*, int)  (0.223946204332)
# 10: [SUMMARY] std::log(float)  (0.195867575235)
# ================================================================================
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] __GI___sched_yield  (21.2451109411)
# 2: [SUMMARY] (anonymous namespace)::MultHelixPropTransp(Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::Matriplex<float, 6, 6, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&)  (9.00434493368)
# 3: [SUMMARY] Matriplex::Matriplex<int, 1, 1, 8>::operator()(int, int, int) const  (5.63956221722)
# 4: [SUMMARY] LayerInfo::is_within_r_sensitive_region(float, float) const  (0.393683020968)
# 5: [SUMMARY] CandCloner::add_cand(int, MkFinder::IdxChi2List const&)  (0.344553093074)
# 6: [SUMMARY] propagateHelixToRMPlex(Matriplex::MatriplexSym<float, 6, 8> const&, Matriplex::Matriplex<float, 6, 1, 8> const&, Matriplex::Matriplex<int, 1, 1, 8> const&, Matriplex::Matriplex<float, 3, 1, 8> const&, Matriplex::MatriplexSym<float, 6, 8>&, Matriplex::Matriplex<float, 6, 1, 8>&, int, bool)  (0.266263277871)
# 7: [SUMMARY] CandCloner::ProcessSeedRange(int, int)  (0.245307338962)
# 8: [SUMMARY] Matriplex::MatriplexSym<float, 3, 8>::SlurpIn(char const*, int*, int)  (0.223946204332)
# 9: [SUMMARY] Matriplex::Matriplex<float, 6, 1, 8>::operator=(Matriplex::Matriplex<float, 6, 1, 8> const&)  (0.176229877696)
# 10: [SUMMARY] void _INTERNAL_19_PropagationMPlex_cc_44bb64a2::helixAtRFromIterativeCCS_impl<Matriplex::Matriplex<float, 6, 1, 8>, Matriplex::Matriplex<int, 1, 1, 8>, Matriplex::Matriplex<float, 6, 1, 8>, Matriplex::Matriplex<float, 1, 1, 8>, Matriplex::Matriplex<float, 6, 6, 8> >(Matriplex::Matriplex<float, 6, 1, 8> const&, Matriplex::Matriplex<int, 1, 1, 8> const&, Matriplex::Matriplex<float, 6, 1, 8>&, Matriplex::Matriplex<float, 1, 1, 8> const&, Matriplex::Matriplex<float, 6, 6, 8>&, int, int, int, bool)  (0.163419634885)

# %%
get_hotspots('PAPI_NATIVE_UOPS_RETIRED:SCALAR_SIMD')
# Out:
# selected metric: PAPI_NATIVE_UOPS_RETIRED:SCALAR_SIMD
#
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] Event::clean_cms_seedtracks()  (329464998)
# 2: [SUMMARY] syscall  (80975056)
# 3: [SUMMARY] _int_malloc  (61421041)
# 4: [SUMMARY] std::__detail::_Mod_range_hashing::operator()(unsigned long, unsigned long) const  (41359694)
# 5: [SUMMARY] std::_Hashtable<int, std::pair<int const, int>, std::allocator<std::pair<int const, int> >, std::__detail::_Select1st, std::equal_to<int>, std::hash<int>, std::__detail::_Mod_range_hashing, std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy, std::__detail::_Hashtable_traits<false, false, true> >::_M_rehash_aux(unsigned long, std::integral_constant<bool, true>)  (39915075)
# 6: [SUMMARY] __GI___libc_malloc  (37976506)
# 7: [SUMMARY] std::_Hashtable<int, std::pair<int const, int>, std::allocator<std::pair<int const, int> >, std::__detail::_Select1st, std::equal_to<int>, std::hash<int>, std::__detail::_Mod_range_hashing, std::__detail::_Default_ranged_hash, std::__detail::_Prime_rehash_policy, std::__detail::_Hashtable_traits<false, false, true> >::_M_insert_unique_node(unsigned long, unsigned long, std::__detail::_Hash_node<std::pair<int const, int>, false>*)  (31559310)
# 8: [SUMMARY] __libm_sse2_sincosf  (24025238)
# 9: [SUMMARY] std::abs(float)  (23378514)
# 10: [SUMMARY] MkFinder::SelectHitIndices(LayerOfHits const&, int)  (21794424)
# ================================================================================
# Hotspot Analysis Summary
# ================================================================================
# The code regions with largest inclusive time are:
# 1: [SUMMARY] Event::clean_cms_seedtracks()  (329464998)
# 2: [SUMMARY] _int_malloc  (61421041)
# 3: [SUMMARY] __GI___libc_malloc  (37976506)
# 4: [SUMMARY] __libm_sse2_sincosf  (24025238)
# 5: [SUMMARY] MkFinder::SelectHitIndices(LayerOfHits const&, int)  (21794424)
# 6: [SUMMARY] UNRESOLVED /storage/packages/intel/vtune_amplifier_xe_2017.5.0.526192/lib64/libstdc++.so.6.0.20 (21279004)
# 7: [SUMMARY] __svml_sincosf8_l9  (19371601)
# 8: [SUMMARY] Track::zAtR(float, float*) const  (14874853)
# 9: [SUMMARY] __libm_tanf_l9  (10859887)
# 10: [SUMMARY] __libm_hypotf_e7  (9827109)
